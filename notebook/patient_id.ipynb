# %%
import os
import pandas as pd

from tqdm import tqdm

#セットアップ
tqdm.pandas()

import sys
sys.path.append("/kaggle/src")
from kaggle_metrics.kaggle_kl_div import compute_each_score

# %%
train = "/kaggle/input/hms-harmful-brain-activity-classification/train.csv"

# %%
train_df = pd.read_csv(train)

# %%
len(train_df)
# Out:
# 106800

# %%
len(train_df["eeg_id"].unique()), len(train_df["patient_id"].unique())
# Out:
# (17089, 1950)

# %%
vote_cols = ['seizure_vote', 'lpd_vote', 'gpd_vote', 'lrda_vote', 'grda_vote', 'other_vote']
for i, id_ in enumerate(train_df["patient_id"].unique()):
    print("patient id:", id_)
    patient_df = train_df[train_df["patient_id"] == id_]
    display(patient_df[vote_cols])
    if i > 5:
        break
# Out:
# patient id: 42516
#         seizure_vote  lpd_vote  gpd_vote  lrda_vote  grda_vote  other_vote
# 0                  3         0         0          0          0           0
# 1                  3         0         0          0          0           0
# 2                  3         0         0          0          0           0
# 3                  3         0         0          0          0           0
# 4                  3         0         0          0          0           0
# 5                  3         0         0          0          0           0
# 6                  3         0         0          0          0           0
# 7                  3         0         0          0          0           0
# 8                  3         0         0          0          0           0
# 13642              3         0         0          0          0           0
# 13643              3         0         0          0          0           0
# ...
